# %% [markdown]
# # Import of Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Spotify Growth Throughout the Years

# %% [markdown]
# ## Quarterly Growth of Monthly Active Users

# %%
# Create dictionaries to store monthly growth data
mau = {"2015 Q1": 68, "2015 Q2": 77, "2015 Q3": 82, "2015 Q4": 91,
       "2016 Q1": 96, "2016 Q2": 104, "2016 Q3": 113, "2016 Q4": 123,
       "2017 Q1": 132, "2017 Q2": 138, "2017 Q3": 149, "2017 Q4": 160,
       "2018 Q1": 157, "2018 Q2": 180, "2018 Q3": 191, "2018 Q4": 207,
       "2019 Q1": 217, "2019 Q2": 232, "2019 Q3": 248, "2019 Q4": 271,
       "2020 Q1": 286, "2020 Q2": 299, "2020 Q3": 320, "2020 Q4": 345,
       "2021 Q1": 356, "2021 Q2": 365, "2021 Q3": 381, "2021 Q4": 406,
       "2022 Q1": 422, "2022 Q2": 433, "2022 Q3": 456, "2022 Q4": 489
      }
premium = {"2015 Q1": 18, "2015 Q2": 22, "2015 Q3": 24, "2015 Q4": 28,
           "2016 Q1": 30, "2016 Q2": 36, "2016 Q3": 40, "2016 Q4": 48,
           "2017 Q1": 52, "2017 Q2": 59, "2017 Q3": 62, "2017 Q4": 71,
           "2018 Q1": 75, "2018 Q2": 83, "2018 Q3": 87, "2018 Q4": 96,
           "2019 Q1": 100, "2019 Q2": 108, "2019 Q3": 113, "2019 Q4": 124,
           "2020 Q1": 130, "2020 Q2": 138, "2020 Q3": 144, "2020 Q4": 155,
           "2021 Q1": 158, "2021 Q2": 165, "2021 Q3": 172, "2021 Q4": 180,
           "2022 Q1": 182, "2022 Q2": 188, "2022 Q3": 195, "2022 Q4": 205
          }

# %%
# Display the actual data
plt.figure(figsize = (10,5))
plt.plot(list(mau.keys()), list(mau.values()), marker = "o", label = "Monthly Active Users")
plt.plot(list(premium.keys()), list(premium.values()), marker = "o", label = "Premium Subscribers")
plt.title("Spotify Quarterly Growth of MAUs and Premium Subscribers (2015-2022)", fontweight = "bold")
plt.xlabel("Quarter")
plt.xticks(rotation = 75)
plt.ylabel("Number of Active Users (Millions)")
plt.legend()
plt.grid()
plt.show();

# %% [markdown]
# ## Annual Financial Revenue

# %%
income = {2009: 0.01336, 2010: 0.0739, 2011: 0.1878, 2012: 0.4301, 2013: 0.746,
          2014: 1.08, 2015: 1.94, 2016: 2.95, 2017: 4.09, 2018: 5.26,
          2019: 6.76, 2020: 7.88, 2021: 9.67, 2022: 11.72
         }
premium = {2009: 0, 2010: 0, 2011: 0, 2012: 0.3746, 2013: 0.67789,
          2014: 0.9827, 2015: 1.74, 2016: 2.657, 2017: 3.67, 2018: 4.717,
          2019: 6.086, 2020: 7.13, 2021: 8.46, 2022: 10.25
          }

# %%
# Display the actual data
plt.figure(figsize = (10,5))
plt.plot(list(income.keys()), list(income.values()), 
         marker = "o", label = "Overall Revenue")
plt.plot(list(premium.keys()), list(premium.values()), 
         marker = "o", label = "Revenue from Premium Subscribers")
plt.title("Spotify Overall Revenue Growth (2009-2022)", fontweight = "bold")
plt.xlabel("Year")
plt.ylabel("Yearly Revenue (Billions)")
plt.legend()
plt.grid()
plt.show();
